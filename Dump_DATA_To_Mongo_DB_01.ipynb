# %% [markdown]
# # MONGO CONNECT - DATA DUMP

# %%
'''YouTube Channel - IDs'''
# UCcAd5Np7fO8SeejB1FVKcYw - BestIndianFood
# UCJrpiw6dS09Zx2Z8d9AFWDA - CricTalks
# UCM1VesJtJ9vTXcMLLr_FfdQ - CokeStudio Playlist
# UCWKAAgM5L7bExQJkPZIbiaw - Tamil Trekker
# UC3QOPapQLnIYErI86ltL_dQ - Nomadic Tamil Guy-50vid
# UC2gbcI8S-Yw6vDYHztk9vLQ - Ammu Mahadevan-27vid
# UCjW5u7vHnvwuXiVQx2ahs4A - Backpacker Kumar-329vid
'''-
api_key = 'AIzaSyDwRTgFFHmLkPbRWsNQFRxWKfJ3LO77rzk'
youtube = build('youtube', 'v3', developerKey=api_key)
-'''

# %%
#
import json
import pandas as pd
from googleapiclient.discovery import build

api_key = 'AIzaSyDwRTgFFHmLkPbRWsNQFRxWKfJ3LO77rzk'
youtube = build('youtube', 'v3', developerKey=api_key)

channel_id = 'UC3QOPapQLnIYErI86ltL_dQ' # Amm - UC2gbcI8S-Yw6vDYHztk9vLQ
# Nomadic - UC3QOPapQLnIYErI86ltL_dQ
# ---------------
#
# Fetchin the channel details:
def get_channel_data(youtube, channel_id): # ----------- 1
    
    channel_response = youtube.channels().list(
    id=channel_id,
    part='snippet,statistics,contentDetails')
    channel_detls = channel_response.execute()
# ---------------
    c_data = dict ( Channel_name = channel_detls['items'][0]['snippet']['title'],
                    Channel_ID = channel_detls['items'][0]['id'],
                    Subscribers = channel_detls['items'][0]['statistics']['subscriberCount'],
                    Views = channel_detls['items'][0]['statistics']['viewCount'],
                    Description = channel_detls['items'][0]['snippet']['description'],
                    Total_Videos = channel_detls['items'][0]['statistics']['videoCount'],
                    Playlist_id = channel_detls['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
                    #videos_id = channel_detls['items'][0]['snippet']['resourceId']['videoId']
                    #'channel_playlists' : cc['items'][0]['contentDetails']['relatedPlaylists']['uploads']
                    )
    return c_data      
# ---------------

getCH = get_channel_data(youtube, channel_id)
playid = (getCH['Playlist_id']) # Getting playlist from the channel

# %%
getCH
# Out:
# {'Channel_name': 'Nomadic Tamil Guy',
#  'Channel_ID': 'UC3QOPapQLnIYErI86ltL_dQ',
#  'Subscribers': '205',
#  'Views': '18948',
#  'Description': '',
#  'Total_Videos': '52',
#  'Playlist_id': 'UU3QOPapQLnIYErI86ltL_dQ'}

# %%
playid # playlist id of the current channel:
# Out:
# 'UU3QOPapQLnIYErI86ltL_dQ'

# %%
Channel_Name = (datac['Channel_name'])
Channel_Name # Name of the current channel:
# Out:
# 'Nomadic Tamil Guy'

# %%
# Fetching the Video_ID Details from Playlist:
def get_videoID_data(youtube, playid): # ----------- 2
    
    vid_details = []
    
    vid_request = youtube.playlistItems().list(
    playlistId=playid,
    maxResults=50,
    part='snippet,contentDetails' # snippet,statistics,contentDetails
    )
    response = vid_request.execute()
    
    for item in response['items']:
        vid_details.append(item['contentDetails']['videoId'])
    
    return vid_details
#
# ---------------
videoID_data = get_videoID_data(youtube, playid)
# ---------------

# %%
videoID_data
# Out:
# ['xngaN6GnhbM',
#  'C8on2HfEED8',
#  'zlX7gy9AtIc',
#  'ca8fGNUHWS4',
#  '8Onzq7DcqGk',
#  'dl3FWbIvepg',
#  'F3XEfQs7EP4',
#  'zIsJHpCSB4k',
#  'iAr7DnIKf2k',
#  'NqmBHrQA1AI',
#  '__RvoG2pSUA',
#  'Qm5Ip7hvY9k',
#  'SOCn-eT9TJc',
#  'sTtfW1utZZs',
#  'X1BMHfM_RyA',
#  'Q8pQ7uI5Reg',
#  'mnTsnOIxGSI',
#  '7o5qCo0DkW4',
#  'umwKSOFbqjM',
#  '4CxzqRxIyXU',
#  'E1I9MW6ZUlc',
#  'pWHiS-6u-Fs',
#  'M575CWo7odg',
#  'oSdtIV1209M',
#  'TuaOHuDzj_s',
#  'YLVz4rLonMg',
#  'M_wfioq8bfc',
#  'HPU-PuOfQC4',
#  '7CbuC6gVZbM',
#  'VWm-K6sqxqc',
#  'lnqYq6rtWhE',
#  'sm66tThqoZw',
#  'i6snKiKttT4',
#  'y5wvAlhvLAI',
#  'vQGTmJergDk',
#  '6BEETa4Eofg',
#  'hkIjTaVTzQY',
#  'CsuLpNOAcTo',
#  'VGzFGsdei3A',
#  '_93Lb5yzQJ0',
#  'Wvpv_BpsJQM',
#  'BJRbagPvF4o',
#  '55f4HNxpdg8',
#  'myh1FhW3K4o',
#  'gZp0wh3vbhA',
#  'g3AoOeKNzOg',
#  'oY2e_flNL4U',
#  'cfgFoO_yUg8',
#  'VmR2o4Xxn24',
#  'se7JzfHKlmQ']

# %%
# videoID_data # All video ids from the channel playlist
print(len(videoID_data))
# Out:
# 50

# %%
# Fetching video details of each video in the playlist:
## 
videoid_details = []

def get_videodetails(youtube, videoID_data): # ----------- 3
    # Fetch video details
    for video_id in videoID_data:
        video_response = youtube.videos().list(
            part='snippet,statistics,contentDetails',
            id=video_id,
            maxResults=50
        ).execute()

        if video_response['items']:
            video_details = {
                "Video_Id": video_id,
                "Video_Name": video_response['items'][0]['snippet']['title'],
                "Video_Description": video_response['items'][0]['snippet']['description'],
                "Video_Statistics": video_response['items'][0]['statistics']['commentCount'],
                "Comment_Count": video_response['items'][0]['statistics'].get('commentCount', 0),
                "View_Count": video_response['items'][0]['statistics'].get('viewCount', 0),
                "Like_Count": video_response['items'][0]['statistics'].get('likeCount', 0),
                "Favorite_Count": video_response['items'][0]['statistics'].get('favoriteCount', 0),
                "Published_At": video_response['items'][0]['snippet']['publishedAt'],
                "Duration": video_response['items'][0]['contentDetails']['duration'],
                "Thumbnail": video_response['items'][0]['snippet']['thumbnails']['default']['url'],
                "Caption_Status": video_response['items'][0]['contentDetails'].get('caption'),
            }
            
            videoid_details.append(video_details)
    
    return videoid_details
# ---------------
getVD = get_videodetails(youtube, videoID_data)

# %%
# get_videodetails(youtube, videoID_data)
print(len(getVD))
# Out:
# 50

# %%
# Fetching the Commands of each videos
## 
v_c_data = []

def get_comments_details(youtube,videoID_data): # ----------- 4
    for i in videoID_data:
        comments_response = youtube.commentThreads().list(
            part='snippet',
            maxResults=2,  # only 2 comments per vios
            videoId=i
        ).execute()
    
        comments = comments_response['items']
        
        for comment in comments:
            comment_information = {
                "Video_iD": i,
                "Comment_Id": comment['snippet']['topLevelComment']['id'],
                "Comment_Text": comment['snippet']['topLevelComment']['snippet']['textDisplay'],
                "Comment_Author": comment['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                "Comment_PublishedAt": comment['snippet']['topLevelComment']['snippet']['publishedAt']
            }

            v_c_data.append(comment_information)
    
    return v_c_data
# ---------------
getCC = get_comments_details(youtube,videoID_data)

# %%
getCC
# Out:
# [{'Video_iD': '8Onzq7DcqGk',
#   'Comment_Id': 'Ugw0Ux2OgqLqvkQHQ5x4AaABAg',
#   'Comment_Text': 'How much u spend for flight ticket bro. <br>Ena airport la irudu namibia poniga',
#   'Comment_Author': 'Imran A',
#   'Comment_PublishedAt': '2023-05-13T15:16:01Z'},
#  {'Video_iD': 'zIsJHpCSB4k',
#   'Comment_Id': 'UgyVojZ6wfEZfPcDV794AaABAg',
#   'Comment_Text': 'selamat datang dan hati hati 🤠',
#   'Comment_Author': 'Dc By',
#   'Comment_PublishedAt': '2023-05-10T12:34:52Z'},
#  {'Video_iD': 'iAr7DnIKf2k',
#   'Comment_Id': 'UgwWMyTJjVZAvJjvkW94AaABAg',
#   'Comment_Text': 'Package details share pannuga bro',
#   'Comment_Author': 'kalai selvan',
#   'Comment_PublishedAt': '2023-04-30T13:37:48Z'},
#  {'Video_iD': 'sTtfW1utZZs',
#   'Comment_Id': 'UgwyAHfM0FSQ_dIx6ZZ4AaABAg',
#   'Comment_Text': 'How much you spend for whole trip bro',
#   'Comment_Author': 'Imran A',
#   'Comment_PublishedAt': '2023-04-12T08:22:08Z'},
#  {'Video_iD': 'Q8pQ7uI5Reg',
# ...

# %%
# getCC
print (len(getCC))
# Out:
# 27

# %%
#
##
ch_df = pd.DataFrame([getCH]) # Channel ID Data Frame
pl_df = pd.DataFrame([videoID_data]) # Playlist ID Data Frame
vd_df = pd.DataFrame([getVD]) # Video details Data Frame
cc_df = pd.DataFrame([getCC]) # Comments Data Frame
##
#
getCH = get_channel_data(youtube, channel_id) # channel details
videoID_data = get_videoID_data(youtube, playid) # playlist details
getVD = get_videodetails(youtube, videoID_data) # video details
getCC = get_comments_details(youtube,videoID_data) # comment details

# %%
ch_df
# Out:
#         Channel_name                Channel_ID Subscribers  Views Description  \
# 0  Nomadic Tamil Guy  UC3QOPapQLnIYErI86ltL_dQ         205  18948
#
#   Total_Videos               Playlist_id
# 0           52  UU3QOPapQLnIYErI86ltL_dQ

# %%
pl_df
# Out:
#             0            1            2            3            4   \
# 0  xngaN6GnhbM  C8on2HfEED8  zlX7gy9AtIc  ca8fGNUHWS4  8Onzq7DcqGk
#
#             5            6            7            8            9   ...  \
# 0  dl3FWbIvepg  F3XEfQs7EP4  zIsJHpCSB4k  iAr7DnIKf2k  NqmBHrQA1AI  ...
#
#             40           41           42           43           44  \
# 0  Wvpv_BpsJQM  BJRbagPvF4o  55f4HNxpdg8  myh1FhW3K4o  gZp0wh3vbhA
#
#             45           46           47           48           49
# 0  g3AoOeKNzOg  oY2e_flNL4U  cfgFoO_yUg8  VmR2o4Xxn24  se7JzfHKlmQ
#
# [1 rows x 50 columns]

# %%
vd_df
# Out:
#                                                   0   \
# 0  {'Video_Id': 'xngaN6GnhbM', 'Video_Name': 'BAL...
#
#                                                   1   \
# 0  {'Video_Id': 'C8on2HfEED8', 'Video_Name': 'Exp...
#
#                                                   2   \
# 0  {'Video_Id': 'zlX7gy9AtIc', 'Video_Name': 'Vin...
#
#                                                   3   \
# 0  {'Video_Id': 'ca8fGNUHWS4', 'Video_Name': 'The...
#
#                                                   4   \
# 0  {'Video_Id': '8Onzq7DcqGk', 'Video_Name': 'sun...
#
#                                                   5   \
# 0  {'Video_Id': 'dl3FWbIvepg', 'Video_Name': 'Thi...
#
#                                                   6   \
# 0  {'Video_Id': 'F3XEfQs7EP4', 'Video_Name': '30 ...
#
#                                                   7   \
# 0  {'Video_Id': 'zIsJHpCSB4k', 'Video_Name': 'Vol...
#
#                                                   8   \
# ...

# %%
cc_df
# Out:
#                                                   0   \
# 0  {'Video_iD': '8Onzq7DcqGk', 'Comment_Id': 'Ugw...
#
#                                                   1   \
# 0  {'Video_iD': 'zIsJHpCSB4k', 'Comment_Id': 'Ugy...
#
#                                                   2   \
# 0  {'Video_iD': 'iAr7DnIKf2k', 'Comment_Id': 'Ugw...
#
#                                                   3   \
# 0  {'Video_iD': 'sTtfW1utZZs', 'Comment_Id': 'Ugw...
#
#                                                   4   \
# 0  {'Video_iD': 'Q8pQ7uI5Reg', 'Comment_Id': 'Ugy...
#
#                                                   5   \
# 0  {'Video_iD': '7o5qCo0DkW4', 'Comment_Id': 'Ugx...
#
#                                                   6   \
# 0  {'Video_iD': 'pWHiS-6u-Fs', 'Comment_Id': 'Ugz...
#
#                                                   7   \
# 0  {'Video_iD': 'M575CWo7odg', 'Comment_Id': 'Ugz...
#
#                                                   8   \
# ...

# %%
# Creating a Mani Dictionary which includes all channel details:
##
Main_data_frame = {
    'Channel': getCH,
    'VideoID': videoID_data,
    'VideoDetail': getVD,
    'Comments': getCC
}

# %%
Main_data_frame
# Out:
# {'Channel': {'Channel_name': 'Nomadic Tamil Guy',
#   'Channel_ID': 'UC3QOPapQLnIYErI86ltL_dQ',
#   'Subscribers': '205',
#   'Views': '18948',
#   'Description': '',
#   'Total_Videos': '52',
#   'Playlist_id': 'UU3QOPapQLnIYErI86ltL_dQ'},
#  'VideoID': ['xngaN6GnhbM',
#   'C8on2HfEED8',
#   'zlX7gy9AtIc',
#   'ca8fGNUHWS4',
#   '8Onzq7DcqGk',
#   'dl3FWbIvepg',
#   'F3XEfQs7EP4',
#   'zIsJHpCSB4k',
#   'iAr7DnIKf2k',
#   'NqmBHrQA1AI',
#   '__RvoG2pSUA',
#   'Qm5Ip7hvY9k',
#   'SOCn-eT9TJc',
#   'sTtfW1utZZs',
#   'X1BMHfM_RyA',
#   'Q8pQ7uI5Reg',
#   'mnTsnOIxGSI',
#   '7o5qCo0DkW4',
#   'umwKSOFbqjM',
#   '4CxzqRxIyXU',
#   'E1I9MW6ZUlc',
#   'pWHiS-6u-Fs',
#   'M575CWo7odg',
#   'oSdtIV1209M',
#   'TuaOHuDzj_s',
#   'YLVz4rLonMg',
#   'M_wfioq8bfc',
#   'HPU-PuOfQC4',
#   '7CbuC6gVZbM',
#   'VWm-K6sqxqc',
#   'lnqYq6rtWhE',
#   'sm66tThqoZw',
#   'i6snKiKttT4',
#   'y5wvAlhvLAI',
#   'vQGTmJergDk',
#   '6BEETa4Eofg',
#   'hkIjTaVTzQY',
#   'CsuLpNOAcTo',
#   'VGzFGsdei3A',
# ...

# %%
Channel_Name
# Out:
# 'Nomadic Tamil Guy'

# %%
Monog_DATA = Channel_Name

# %%
Monog_DATA
# Out:
# 'Nomadic Tamil Guy'

# %% [markdown]
# # DUMPING DATA TO MONGO DB LAKE

# %%
#
Channel_Name = (datac['Channel_name'])
# Channel_Name
Monog_DATA = Channel_Name
#

# %%
"""
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycollection = mydb.create_collection("mycollection")
print("Collection created successfully!")

"""

# %%
"""
# Create a database
mydb = myclient["mydatabase"]

# Create a collection
mycollection = mydb["mycollection"]

# Select the database and collection

db = client["YTubeData"]
collection = db["tubefulldata"]

# Retrieve the data from the MongoDB collection
data = list(collection.find())

# Retrieve the channel name from the data
Channel_Name = (datac['Channel_name'])

# Create the collection with the channel name
collection = db[Channel_Name]
"""

# %%
#
##
import pymongo
import pandas as pd

# Create a MongoClient instance to connect to the MongoDB server
client = pymongo.MongoClient("mongodb://localhost:27017")

# Select the database
db = client["youtubeid"]
collection = db["Nomadic_Tamil_Guy"]
#
x = collection.insert_one(Main_data_frame) # Inserting the *** DATA into Mongo DB ***
x
#

# %%
x = collection.insert_one(Main_data_frame) # Inserting the *** DATA into Mongo DB ***
x
# Collection - is the Variable that is used to store the collection(table) data

# %%
print(client.list_database_names()) # Show Data base in Mongo DB:
# Out:
# ['FoodApps', 'admin', 'config', 'local', 'myytdb', 'test01', 'youtubeid']

# %%
print(db.list_collection_names()) # Show Collections in the Mongo DB Data Base:
# Out:
# ['sampleYTPL', 'sampleYTCC', 'Nomadic Tamil Guy', 'sampleTYCD', 'sampleYTVID', 'Nomadic_Tamil_Guy', 'tubefulldata']

# %% [markdown]
# # SQL Fetch & Creat Table

# %%
import mysql.connector
from pymongo import MongoClient

# MongoDB Connection ----------------------------------------
mongo_conn_str = 'mongodb://localhost:27017/'
mongo_client = MongoClient(mongo_conn_str)
mongo_db = mongo_client['youtubeid']
#
# Select the desired collection in MongoDB
mongo_collection0 = mongo_db['Nomadic Tamil Guy'] # test the New Colletion "-Nomadic Tamil Guy-"
mongo_collection1 = mongo_db['Nomadic Tamil Guy']
mongo_collection2 = mongo_db['Nomadic Tamil Guy']
mongo_collection3 = mongo_db['Nomadic Tamil Guy']

# Fetch data from the MongoDB collection
mongo_data = list(mongo_collection0.find()) # channel details
mongo_data1 = list(mongo_collection1.find()) # video details
mongo_data2 = list(mongo_collection2.find()) # comments details
mongo_data3 = list(mongo_collection3.find()) # playlist details

# MySQL Connection ----------------------------------------
mysql_conn = mysql.connector.connect(
    host='127.0.0.1',
    user='root',
    password='sql@123456789',
    port=3307,
    database='httable'
)

# Create MySQL table ----------------------------------------
mysql_cursor = mysql_conn.cursor()
#

# %%
# Function Creation 01:

def get_sqlchannel_data():
    
    mysql_create_table = """CREATE TABLE nomadic_mysql_chtable
    (
    Channel_name VARCHAR(255),
    Channel_ID VARCHAR(255),
    Subscribers INT,
    Views INT,
    Description TEXT,
    Total_Videos INT,
    Playlist_id VARCHAR(255)
    )"""
    
    mysql_cursor.execute(mysql_create_table)
    
    # Fetch data from MongoDB collection
    mongo_data = mongo_collection0.find()
    
    # Insert data into MySQL table
    for document in mongo_data:
        
        Channel_name = document["Channel"]["Channel_name"]
        Channel_ID = document["Channel"]["Channel_ID"]
        Subscribers = document["Channel"]["Subscribers"]
        Views = document["Channel"]["Views"]
        Description = document["Channel"]["Description"]
        Total_Videos = document["Channel"]["Total_Videos"]
        Playlist_id = document["Channel"]["Playlist_id"]

        mysql_query = """
        INSERT INTO nomadic_mysql_chtable (
            Channel_name, Channel_ID, Subscribers, Views, Description, Total_Videos, Playlist_id
        ) VALUES (
            # %s, %s, %s, %s, %s, %s, %s
        )
        """
        mysql_values = (
            Channel_name, Channel_ID, Subscribers, Views, Description, Total_Videos, Playlist_id
        )
        mysql_cursor.execute(mysql_query, mysql_values)

        
    mysql_cursor.execute("""select * from httable.nomadic_mysql_chtable""")

    # Fetch the results of the query
    rows = mysql_cursor.fetchall()

    # Print the rows
    for row in rows:
        print(row)
    
    
    return rows

# %%
#
get_sqlchannel_data()
# print(get_sqlchannel_data())

# %%
# Function Creation 02:

def get_sqlchannelvideo_data():
    mysql_create_table = """CREATE TABLE nomadic_mysql_vitable01
    (
    Video_Id VARCHAR(255),
    Video_Name VARCHAR(255),
    Video_Description TEXT,
    Video_Statistics VARCHAR(255),
    Comment_Count INT,
    View_Count INT,
    Like_Count INT,
    Favorite_Count INT,
    Published_At VARCHAR(255),
    Duration VARCHAR(255),
    Thumbnail VARCHAR(255),
    Caption_Status VARCHAR(255)
    )"""
    
    mysql_cursor.execute(mysql_create_table)
    
    # Fetch data from MongoDB collection
    mongo_data1 = mongo_collection1.find()
    
    # Insert data into MySQL table
    for document1 in mongo_data1:
        
        for video_detail in document1["VideoDetail"]:
        
            Video_Id = video_detail["Video_Id"]
            Video_Name = video_detail["Video_Name"]
            Video_Description = video_detail["Video_Description"]
            Video_Statistics = video_detail["Video_Statistics"]
            Comment_Count = video_detail["Comment_Count"]
            View_Count = video_detail["View_Count"]
            Like_Count = video_detail["Like_Count"]
            Favorite_Count = video_detail["Favorite_Count"]
            Published_At = video_detail["Published_At"]
            Duration = video_detail["Duration"]
            Thumbnail = video_detail["Thumbnail"]
            Caption_Status = video_detail["Caption_Status"]


            mysql_query1 = """
            INSERT INTO nomadic_mysql_vitable01 (
                Video_Id, Video_Name, Video_Description, Video_Statistics, Comment_Count, View_Count, Like_Count,Favorite_Count, Published_At, Duration, Thumbnail, Caption_Status 
            ) VALUES (
                # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
            )
            """
            mysql_values1 = (
                Video_Id, Video_Name, Video_Description, Video_Statistics, Comment_Count, View_Count, Like_Count,Favorite_Count, Published_At, Duration, Thumbnail, Caption_Status
            )
            mysql_cursor.execute(mysql_query1, mysql_values1)

    
        mysql_cursor.execute("""select * from httable.nomadic_mysql_vitable01""")

        # Fetch the results of the query
        rows1 = mysql_cursor.fetchall()
    
        # Print the rows
        for row1 in rows1:
            print(row1)
       
    return rows1
#

# %%
#
get_sqlchannelvideo_data()
# print(get_sqlchannelvideo_data())

# %%
# 02 comments:
# Function Creation 03:
def get_sqlchannelcomments_datas():
    mysql_create_table = """CREATE TABLE nomadic_mysql_cctable
    (
      Video_id VARCHAR(255),
      Comment_id VARCHAR(255),
      Comment_text TEXT,
      Comment_author VARCHAR(255),
      Comment_PublishedAt VARCHAR(255)
    )"""

    mysql_cursor.execute(mysql_create_table)

    # Insert data into MySQL table
    for document2 in mongo_data2:
        for cc_detail in document2["Comments"]:
            Video_iD = cc_detail["Video_iD"]
            Comment_Id = cc_detail["Comment_Id"]
            Comment_Text = cc_detail["Comment_Text"]
            Comment_Author = cc_detail["Comment_Author"]
            Comment_PublishedAt = cc_detail["Comment_PublishedAt"]

            mysql_query2 = """
            INSERT INTO nomadic_mysql_cctable (
                Video_iD, Comment_Id, Comment_Text, Comment_Author, Comment_PublishedAt
            ) VALUES (
                # %s, %s, %s, %s, %s
            )
            """
            mysql_values2 = (
                Video_iD, Comment_Id, Comment_Text, Comment_Author, Comment_PublishedAt
            )
            mysql_cursor.execute(mysql_query2, mysql_values2)

        mysql_cursor.execute("""select * from httable.nomadic_mysql_cctable""")

        # Fetch the results of the query
        rows2 = mysql_cursor.fetchall()

        # Print the rows
        for row2 in rows2:
            print(row2)

    return rows2
#

# %%
get_sqlchannelcomments_datas()

# %%
# Function Creation 04: -- MY CODE --

def get_sqlchannelplaylist_datas():
    
    mysql_create_table = """CREATE TABLE nomadic_mysql_pltable04( VideoID VARCHAR(255) )"""

    mysql_cursor.execute(mysql_create_table)
    
    # Insert data into the SQL table
    for document3 in mongo_data3:
        video_pliD = document3["VideoID"]
        mysql_query3 = "INSERT INTO nomadic_mysql_pltable04 (VideoID) VALUES (%s)"
        mysql_values3 = [(video_id,) for video_id in video_pliD]
        mysql_cursor.executemany(mysql_query3, mysql_values3)
        # value = [(i,) for i in video_id] # list comprehension
    
    mysql_cursor.execute("""select * from httable.nomadic_mysql_pltable04""")

    # Fetch the results of the query
    rows3 = mysql_cursor.fetchall()

    # Print the rows
    for row3 in rows3:
        print(row3)
    
    return rows3

# %%
get_sqlchannelplaylist_datas()
